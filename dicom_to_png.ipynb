# %%
import matplotlib.pyplot as plt
import pydicom
from pydicom.data import get_testdata_files
filename = "1-24.dcm"
ds = pydicom.dcmread(filename)
plt.imshow(ds.pixel_array, cmap=plt.cm.bone)
plt.axis("off")
plt.savefig('lung.png',dpi=1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3e8071830104> in <module>
#       5 ds = pydicom.dcmread(filename)
#       6 plt.imshow(ds.pixel_array, cmap=plt.cm.bone)
# ----> 7 plt.axis(none)
#       8 plt.savefig('lung.png',dpi=1000)
#       9
#
# NameError: name 'none' is not defined
